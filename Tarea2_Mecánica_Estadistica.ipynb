# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloAndagana/Tarea-2-Mecanica-Estadastica---PUC/blob/main/Tarea2_Mec%C3%A1nica_Estadistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#P1, implementar el pseudo algoritmo para direc_pi

import random
import numpy as np
import matplotlib.pyplot as plt

def direct_pi(N):
  N_hits = 0

  for i in range(N):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if x**2 + y**2 <= 1:
      N_hits += 1

  return N_hits

#Creamos los valores en los que se va a correr la función y el arreglo para
#almacenar la desviación estandar

N_vals = [10, 100, 1000, 10000, 100000, 1000000, 10000000]
desvs_std = []

for N in N_vals:
  desvs = []
  for i in range(20):
    N_hits = direct_pi(N)
    desv = (N_hits/N - np.pi/4)**2
    desvs.append(desv)

  desv_std = np.sqrt(np.mean(desvs))
  desvs_std.append(desv_std)
  print(f'N = {N}, Desviacion cuadrática media: {desv_std}')
# Out:
# N = 10, Desviacion cuadrática media: 0.1349563397257336
# N = 100, Desviacion cuadrática media: 0.034280585381394356
# N = 1000, Desviacion cuadrática media: 0.01671714817937635
# N = 10000, Desviacion cuadrática media: 0.003672017695730787
# N = 100000, Desviacion cuadrática media: 0.0012299265929912354
# N = 1000000, Desviacion cuadrática media: 0.0004167028780013389
# N = 10000000, Desviacion cuadrática media: 8.196998573105707e-05

# %%
plt.figure(figsize=(8, 6))
plt.plot(N_vals, desvs_std, marker='o', linestyle='-', color='blue')
plt.xlabel('N')
plt.xscale('log')
plt.ylabel('$<(N_{hits}/N - \pi/4)^2>$')
plt.title('Desviación cuadrática media vs Número de trials')
plt.grid(True, axis = 'y', ls="--")
plt.show()
